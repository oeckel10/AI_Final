# %%
import random
import json
import os
from scipy.spatial import distance

def generate_points_and_distances(id, output_folder, num_holes=100):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    rectangle_width = random.randint(10, 200)
    rectangle_height = random.randint(10, 200)

    # Randomly assign 20 points within this rectangle
    points = [(random.randint(1, rectangle_width-1), random.randint(1, rectangle_height-1)) for _ in range(num_holes)]
    points.append((0, 0))
    points.insert(0, (0, 0))
    # Calculate the distances between all these points
    distances = []
    for i in range(len(points)):
        row = []
        for j in range(len(points)):
            if i == j:
                row.append(0)
            else:
                dist = distance.euclidean(points[i], points[j])
                row.append(dist)
        distances.append(row)
    
    # make the first row and column all -1
    for i in range(1, len(distances)):
        distances[i][0] = -1
    for i in range(len(distances)-1):
        distances[-1][i] = -1

    # Create the JSON structure
    json_data = {
        "Name": f"scenario_{id}",
        "Size": len(points),
        "Distances": distances,
        "Coordinates": points,
    }

    # Save these distances in a JSON file
    json_filename = os.path.join(output_folder, f'scenario_{id}.json')
    with open(json_filename, 'w') as f:
        # save the data without indenting the inner lists
        json.dump(json_data, f, indent=0)
        

    print(f"Distances saved in '{json_filename}'")

def call_generate_points_and_distances_multiple_times(id_prefix, output_folder, num_calls, num_holes=20, random_holes=False, min_holes=10, max_holes=100, start_id=0):
    for i in range(start_id, start_id + num_calls):
        current_id = f"{id_prefix}_{i+1}"
        if random_holes:
            num_holes = random.randint(min_holes, max_holes)
        generate_points_and_distances(current_id, output_folder, num_holes)

# Example usage
script_dir = os.getcwd()
call_generate_points_and_distances_multiple_times('example_id', os.path.join(script_dir, 'generated_scenarios'), num_calls=10000, start_id = 0, random_holes=False, num_holes=20)
# Out:
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_1.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_2.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_3.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_4.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_5.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_6.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_7.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_8.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_9.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_10.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_11.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_12.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_13.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_14.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_15.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_16.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_17.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_18.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_19.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_20.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_21.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_22.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_23.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_24.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_25.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_26.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_27.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_28.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_29.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_30.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_31.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_32.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_33.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_34.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_35.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_36.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_37.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_38.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_39.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_40.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_41.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_42.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_43.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_44.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_45.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_46.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_47.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_48.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_49.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_50.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_51.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_52.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_53.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_54.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_55.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_56.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_57.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_58.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_59.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_60.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_61.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_62.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_63.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_64.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_65.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_66.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_67.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_68.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_69.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_70.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_71.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_72.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_73.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_74.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_75.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_76.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_77.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_78.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_79.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_80.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_81.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_82.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_83.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_84.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_85.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_86.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_87.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_88.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_89.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_90.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_91.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_92.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_93.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_94.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_95.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_96.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_97.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_98.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_99.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_100.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_101.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_102.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_103.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_104.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_105.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_106.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_107.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_108.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_109.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_110.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_111.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_112.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_113.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_114.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_115.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_116.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_117.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_118.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_119.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_120.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_121.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_122.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_123.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_124.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_125.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_126.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_127.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_128.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_129.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_130.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_131.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_132.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_133.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_134.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_135.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_136.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_137.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_138.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_139.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_140.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_141.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_142.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_143.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_144.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_145.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_146.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_147.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_148.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_149.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_150.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_151.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_152.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_153.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_154.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_155.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_156.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_157.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_158.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_159.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_160.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_161.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_162.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_163.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_164.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_165.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_166.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_167.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_168.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_169.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_170.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_171.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_172.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_173.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_174.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_175.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_176.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_177.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_178.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_179.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_180.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_181.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_182.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_183.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_184.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_185.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_186.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_187.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_188.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_189.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_190.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_191.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_192.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_193.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_194.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_195.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_196.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_197.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_198.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_199.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_200.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_201.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_202.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_203.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_204.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_205.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_206.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_207.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_208.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_209.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_210.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_211.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_212.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_213.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_214.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_215.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_216.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_217.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_218.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_219.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_220.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_221.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_222.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_223.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_224.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_225.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_226.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_227.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_228.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_229.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_230.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_231.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_232.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_233.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_234.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_235.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_236.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_237.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_238.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_239.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_240.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_241.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_242.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_243.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_244.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_245.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_246.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_247.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_248.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_249.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_250.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_251.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_252.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_253.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_254.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_255.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_256.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_257.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_258.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_259.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_260.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_261.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_262.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_263.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_264.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_265.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_266.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_267.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_268.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_269.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_270.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_271.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_272.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_273.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_274.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_275.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_276.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_277.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_278.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_279.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_280.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_281.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_282.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_283.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_284.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_285.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_286.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_287.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_288.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_289.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_290.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_291.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_292.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_293.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_294.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_295.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_296.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_297.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_298.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_299.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_300.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_301.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_302.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_303.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_304.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_305.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_306.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_307.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_308.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_309.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_310.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_311.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_312.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_313.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_314.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_315.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_316.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_317.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_318.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_319.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_320.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_321.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_322.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_323.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_324.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_325.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_326.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_327.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_328.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_329.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_330.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_331.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_332.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_333.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_334.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_335.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_336.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_337.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_338.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_339.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_340.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_341.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_342.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_343.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_344.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_345.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_346.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_347.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_348.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_349.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_350.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_351.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_352.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_353.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_354.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_355.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_356.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_357.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_358.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_359.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_360.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_361.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_362.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_363.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_364.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_365.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_366.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_367.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_368.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_369.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_370.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_371.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_372.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_373.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_374.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_375.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_376.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_377.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_378.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_379.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_380.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_381.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_382.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_383.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_384.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_385.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_386.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_387.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_388.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_389.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_390.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_391.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_392.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_393.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_394.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_395.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_396.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_397.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_398.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_399.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_400.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_401.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_402.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_403.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_404.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_405.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_406.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_407.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_408.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_409.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_410.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_411.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_412.json'
# Distances saved in 'c:\Users\maxap\Documents\AI_THU_WS\final_project\generated_scenarios\scenario_example_id_413.json'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 61
#      59 # Example usage
#      60 script_dir = os.getcwd()
# ---> 61 call_generate_points_and_distances_multiple_times('example_id', os.path.join(script_dir, 'generated_scenarios'), num_calls=10000, start_id = 0, random_holes=False, min_holes=2, max_holes=20)
#
# Cell In[31], line 57, in call_generate_points_and_distances_multiple_times(id_prefix, output_folder, num_calls, num_holes, random_holes, min_holes, max_holes, start_id)
#      55 if random_holes:
#      56     num_holes = random.randint(min_holes, max_holes)
# ---> 57 generate_points_and_distances(current_id, output_folder, num_holes)
#
# Cell In[31], line 25, in generate_points_and_distances(id, output_folder, num_holes)
#      23         row.append(0)
#      24     else:
# ---> 25         dist = distance.euclidean(points[i], points[j])
#      26         row.append(dist)
#      27 distances.append(row)
#
# File c:\Users\maxap\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\spatial\distance.py:520, in euclidean(u, v, w)
#     484 def euclidean(u, v, w=None):
#     485     """
#     486     Computes the Euclidean distance between two 1-D arrays.
#     487
#    (...)
#     518
#     519     """
# --> 520     return minkowski(u, v, p=2, w=w)
#
# File c:\Users\maxap\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\spatial\distance.py:480, in minkowski(u, v, p, w)
#     478         root_w = np.power(w, 1/p)
#     479     u_v = root_w * u_v
# --> 480 dist = norm(u_v, ord=p)
#     481 return dist
#
# File c:\Users\maxap\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\linalg\_misc.py:178, in norm(a, ord, axis, keepdims, check_finite)
#     175             return lange(*lange_args)
#     177 # fall back to numpy in every other case
# --> 178 return np.linalg.norm(a, ord=ord, axis=axis, keepdims=keepdims)
#
# File c:\Users\maxap\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\linalg\linalg.py:2537, in norm(x, ord, axis, keepdims)
#    2534 x = asarray(x)
#    2536 if not issubclass(x.dtype.type, (inexact, object_)):
# -> 2537     x = x.astype(float)
#    2539 # Immediately handle some default, simple, fast, and common cases.
#    2540 if axis is None:
#
# KeyboardInterrupt:
